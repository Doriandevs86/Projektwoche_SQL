# %%
import psycopg
import pandas as pd
from getpass import getpass
from sqlalchemy.orm import Session
from sqlalchemy import Text, create_engine

# %%
#check_in:
pw = getpass('Please enter password: ')

with psycopg.connect(
    host='localhost',
    port='5432',
    user='postgres',
    password=pw,
    dbname='musikdaten',
    autocommit=True
) as connection:
    print("psycopg connected!")

# connection SQLAlchemy:
pw = getpass('Please enter password: ')

connection_url = f'postgresql://postgres:{pw}@localhost:5432/musikdaten'
engine = create_engine(connection_url)

# check connection:
with engine.connect() as conn_alchemy:
    print("SQLAlchemy connected!")
# Out:
# psycopg connected!
# SQLAlchemy connected!

# %%
data = pd.read_csv(r'C:\Projekte\Projektwoche_SQL\src\database\spotify_songs.csv')

data
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
select_stmt ='SELECT tempo, danceability,energy, track_id, track_name from "spotify_songs"';

# %%
select_stmt
# Out:
# 'SELECT tempo, danceability,energy, track_id, track_name from "spotify_songs"'

# %%
dataframe = pd.read_sql(select_stmt, engine)

# %%
dataframe
# Out:
#          tempo  danceability  energy                track_id  \
# 0      122.036         0.748   0.916  6f807x0ima9a1j3VPbc7VN
# 1       99.972         0.726   0.815  0r7CVbZTWZgbTCYdfa2P31
# 2      124.008         0.675   0.931  1z1Hg7Vb0AhHDiEmnDE79l
# 3      121.956         0.718   0.930  75FpbthrwQmzHlBJLuGdC7
# 4      123.976         0.650   0.833  1e8PAfcKUYoKkxPhrHqw4x
# ...        ...           ...     ...                     ...
# 32819   128.17         0.428   0.922  7bxnKAamR3snQ1VGLuVfC1
# 32820  128.041         0.522   0.786  5Aevni09Em4575077nkWHz
# 32821  127.989         0.529   0.821  7ImMqPP3Q1yfUHvsdn7wEo
# 32822  128.008         0.626   0.888  2m69mhnfQ1Oq6lGtXuYhgX
# 32823  127.984         0.603   0.884  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...
# 1                        Memories - Dillon Francis Remix
# 2                        All the Time - Don Diablo Remix
# ...

# %%
dataframe.to_sql("Tracks", engine)
# Out:
# 824
